# %% [markdown]
# # Install requirements to run the notebooks
#
# The required Python packages are in `requirements.txt`, you can install them manually or install everything with:

# %%
#!uv pip install -r requirements.txt

# %% [markdown]
# # Optional: Install Jupyter Widgets
#
# - <https://ipywidgets.readthedocs.io/en/stable/user_install.html>
#
# ## With pip
#
# ```
# pip install ipywidgets
# ```
#
# ## With Conda
#
# ```
# conda install -c conda-forge ipywidgets
# ```

# %%
# !conda install -c conda-forge ipywidgets
# Out:
# Channels:
#  - conda-forge
# Platform: osx-arm64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/saharmohamed/miniforge3/envs/sap_env
#
#   added / updated specs:
#     - ipywidgets
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ipywidgets-8.1.8           |     pyhd8ed1ab_0         112 KB  conda-forge
#     jupyterlab_widgets-3.0.16  |     pyhcf101f3_1         212 KB  conda-forge
#     widgetsnbextension-4.0.15  |     pyhd8ed1ab_0         868 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         1.2 MB
#
# The following NEW packages will be INSTALLED:
#
#   ipywidgets         conda-forge/noarch::ipywidgets-8.1.8-pyhd8ed1ab_0
#   jupyterlab_widgets conda-forge/noarch::jupyterlab_widgets-3.0.16-pyhcf101f3_1
#   widgetsnbextension conda-forge/noarch::widgetsnbextension-4.0.15-pyhd8ed1ab_0
#
#
# Proceed ([y]/n)? ^C

# %%
# Test widgets

# %%
import ipywidgets as ipw

def f(x):
    return x

ipw.interact(f, x=10);
# Out:
# interactive(children=(IntSlider(value=10, description='x', max=30, min=-10), Output()), _dom_classes=('widget-…
